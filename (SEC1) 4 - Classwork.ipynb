# %% [markdown]
# # HR ATTRIBUTION

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer, f1_score
import numpy as np
from sklearn.metrics import confusion_matrix, roc_curve, roc_auc_score, auc
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
from sklearn import tree  
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer, roc_auc_score
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import accuracy_score

# %% [markdown]
# # 1.) Import, split data into X/y, plot y data as bar charts, turn X categorical variables binary and tts.

# %%
df = pd.read_csv("HR_Analytics.csv")
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 0  ...                         1            80                 0
# 1  ...                         4            80                 1
# 2  ...                         2            80                 0
# 3  ...                         3            80                 0
# 4  ...                         4            80                 1
#
#    TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 0                  8                      0               1               6
# 1                 10                      3               3              10
# 2                  7                      3               3               0
# 3                  8                      3               3               8
# 4                  6                      3               3               2
#
#   YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 0                  4                        0                     5
# 1                  7                        1                     7
# 2                  0                        0                     0
# 3                  7                        3                     0
# 4                  2                        2                     2
#
# [5 rows x 35 columns]

# %%
y = df[["Attrition"]].copy()
X = df.drop("Attrition", axis = 1)

# %%
y["Attrition"] = [1 if i == "Yes" else 0 for i in y["Attrition"]]

# %%
class_counts = y.value_counts()


plt.figure(figsize=(8, 6))
class_counts.plot(kind='bar', color='skyblue')
plt.xlabel('Class')
plt.ylabel('Count')
plt.title('Class Distribution')
plt.xticks(rotation=0)  # Remove rotation of x-axis labels
plt.show()

# %%
# Step 1: Identify string columns
string_columns = X.columns[X.dtypes == 'object']

# Step 2: Convert string columns to categorical
for col in string_columns:
    X[col] = pd.Categorical(X[col])

# Step 3: Create dummy columns
X = pd.get_dummies(X, columns=string_columns, prefix=string_columns,drop_first=True)

# %%
x_train,x_test,y_train,y_test=train_test_split(X,
 y, test_size=0.20, random_state=42)

# %% [markdown]
# # 2.) Using the default Decision Tree. What is the IN/Out of Sample accuracy?

# %%
clf = DecisionTreeClassifier()
clf.fit(x_train,y_train)
y_pred=clf.predict(x_train)
acc=accuracy_score(y_train,y_pred)
print("IN SAMPLE ACCURACY : " , round(acc,2))

y_pred=clf.predict(x_test)
acc=accuracy_score(y_test,y_pred)
print("OUT OF SAMPLE ACCURACY : " , round(acc,2))
# Out:
# IN SAMPLE ACCURACY :  1.0
# OUT OF SAMPLE ACCURACY :  0.77

# %%
#cut the tree early, since the model is over fit to the insample data

# %% [markdown]
# # 3.) Run a grid search cross validation using F1 score to find the best metrics. What is the In and Out of Sample now?

# %%
# Define the hyperparameter grid to search through
param_grid = {
    'criterion': ['gini', 'entropy'],
    'max_depth': np.arange(1, 11),  # Range of max_depth values to try
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}


dt_classifier = DecisionTreeClassifier(random_state=42)

scoring = make_scorer(f1_score, average='weighted')

grid_search = GridSearchCV(estimator=dt_classifier, param_grid=param_grid, scoring=scoring, cv=5)

grid_search.fit(x_train, y_train)

# Get the best parameters and the best score
best_params = grid_search.best_params_
best_score = grid_search.best_score_

print("Best Parameters:", best_params)
print("Best F1-Score:", best_score)
# Out:
# Best Parameters: {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 2, 'min_samples_split': 2}
# Best F1-Score: 0.8214764475510983

# %%
clf = tree.DecisionTreeClassifier(**best_params, random_state =42)
clf.fit(x_train,y_train)
y_pred=clf.predict(x_train)
acc=accuracy_score(y_train,y_pred)
print("IN SAMPLE ACCURACY : " , round(acc,2))

y_pred=clf.predict(x_test)
acc=accuracy_score(y_test,y_pred)
print("OUT OF SAMPLE ACCURACY : " , round(acc,2))
# Out:
# IN SAMPLE ACCURACY :  0.91
# OUT OF SAMPLE ACCURACY :  0.83

# %% [markdown]
# # 4.) Plot ......

# %%
# Make predictions on the test data
y_pred = clf.predict(x_test)
y_prob = clf.predict_proba(x_test)[:, 1]

# Calculate the confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
plt.imshow(conf_matrix, interpolation='nearest', cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.colorbar()
tick_marks = np.arange(len(conf_matrix))
plt.xticks(tick_marks, ['Class 0', 'Class 1'], rotation=45)
plt.yticks(tick_marks, ['Class 0', 'Class 1'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()


feature_importance = clf.feature_importances_  #by which is first splitted

# Sort features by importance and select the top 10
top_n = 10
top_feature_indices = np.argsort(feature_importance)[::-1][:top_n]
top_feature_names = X.columns[top_feature_indices]
top_feature_importance = feature_importance[top_feature_indices]

# Plot the top 10 most important features
plt.figure(figsize=(10, 6))
plt.bar(top_feature_names, top_feature_importance)
plt.xlabel('Feature')
plt.ylabel('Importance Score')
plt.title('Top 10 Most Important Features - Decision Tree')
plt.xticks(rotation=45)
plt.show()

# Plot the Decision Tree for better visualization of the selected features
plt.figure(figsize=(12, 6))
plot_tree(clf, filled=True, feature_names=X.columns, class_names=["Yes", "No"], rounded=True, fontsize=4)
plt.title('Decision Tree Classifier')
plt.show()

# %% [markdown]
# # 5.) Looking at the graphs. what would be your suggestions to try to improve employee retention? What additional information would you need for a better plan. Calculate & Plot anything you think would assist in your assessment

# %% [markdown]
# ## ANSWER :

# %% [markdown]
# Looking at the graph, to stop retention, the company could rise the monthly income, but we need to figure out which way the overtime pay directs.

# %%
from scipy.stats import pearsonr

# %%
def calculate_correlation(X, feature_name, y):
    feature = X[feature_name]
    
    coef, _= pearsonr(feature, y)
    
    return(coef)

# %%
np.corrcoef(np.array(X['OverTime_Yes']), np.array(y['Attrition']))
# Out:
# array([[1.        , 0.24611799],
#        [0.24611799, 1.        ]])

# %% [markdown]
# The correlation show, Working overtime leads to attrition

# %% [markdown]
# # 6.) Using the Training Data, if they made everyone work overtime. Made no one work overtime. What would have been the expected difference in attrition?

# %%
x_train_experiment = x_train.copy()

# %%
x_train_experiment['OverTime_Yes'] = 0

# %%
y_pred = clf.predict(x_train)
y_pred_experiment = clf.predict(x_train_experiment)

# %%
diff = sum(y_pred - y_pred_experiment)
print('Change from...', diff)
# Out:
# Change from... 59

# %% [markdown]
# we keep people work overtime, thre will be extra more 59 employees from leaving

# %% [markdown]
# # 7.) If they company loses an employee, there is a cost to train a new employee for a role ~2.8 * their monthly income.
# # To make someone not work overtime costs the company 2K per person.
# # Is it profitable for the company to remove overtime? If so/not by how much?
# # What do you suggest to maximize company profits?

# %% [markdown]
# if people work overtime, they cost company.

# %%
x_train_experiment['Y'] = y_pred
x_train_experiment['Y_exp'] = y_pred_experiment

# %%
x_train_experiment['Ret_Change'] = x_train_experiment['Y_exp'] -  x_train_experiment['Y']

# %%
sav = sum(-2.8 * x_train_experiment['Ret_Change']* x_train_experiment['MonthlyIncome'])
cost = len(x_train[x_train['OverTime_Yes'] == 1])*2000

# %%
sav - cost
# Out:
# -117593.99999999977

# %% [markdown]
# The cost is higher for not keeping people work overtime. It is more profitable for keep them working, and keep them busy is profitable.

# %% [markdown]
# ## ANSWER :

# %% [markdown]
# # 8.) Use your model and get the expected change in retention for raising and lowering peoples income. Plot the outcome of the experiment. Comment on the outcome of the experiment and your suggestions to maximize profit.

# %%
#put the above in for loop

# %%
raise_amount = 100

# %%
profit = []

for raise_amount in range(-1000, 1000, 10):
    x_train_experiment = x_train.copy()
    x_train_experiment['MonthlyIncome'] = x_train_experiment['MonthlyIncome'] + raise_amount
    y_pred = clf.predict(x_train)
    y_pred_experiment = clf.predict(x_train_experiment)
    diff = sum(y_pred - y_pred_experiment)
    print('Change from attrition', diff)
    x_train_experiment['Y'] = y_pred
    x_train_experiment['Y_exp'] = y_pred_experiment
    x_train_experiment['Ret_Change'] = x_train_experiment['Y_exp'] -  x_train_experiment['Y']
    sav = sum(-2.8 * x_train_experiment['Ret_Change']* x_train_experiment['MonthlyIncome'])
    cost = len(x_train)*raise_amount
    
    print('Profit,', sav-cost)
    profit.append(sav - cost)
# Out:
# Change from attrition -16
# Profit, 1087584.4
# Change from attrition -16
# Profit, 1075376.4
# Change from attrition -16
# Profit, 1063168.4
# Change from attrition -16
# Profit, 1050960.4
# Change from attrition -16
# Profit, 1038752.4
# Change from attrition -16
# Profit, 1026544.4
# Change from attrition -15
# Profit, 1021277.6
# Change from attrition -15
# Profit, 1009097.6
# Change from attrition -15
# Profit, 996917.6
# Change from attrition -14
# Profit, 991676.0
# Change from attrition -14
# Profit, 979524.0
# Change from attrition -14
# Profit, 967372.0
# Change from attrition -14
# Profit, 955220.0
# Change from attrition -14
# Profit, 943062.4
# Change from attrition -14
# Profit, 930910.4
# Change from attrition -14
# Profit, 918758.4
# Change from attrition -14
# Profit, 906606.4
# Change from attrition -14
# Profit, 894454.4
# Change from attrition -13
# Profit, 889240.8
# Change from attrition -13
# Profit, 877116.8
# Change from attrition -13
# Profit, 864992.8
# Change from attrition -13
# Profit, 852868.8
# Change from attrition -13
# Profit, 840744.8
# Change from attrition -13
# Profit, 828620.8
# Change from attrition -13
# Profit, 816496.8
# Change from attrition -13
# Profit, 804372.8
# Change from attrition -13
# Profit, 792248.8
# Change from attrition -13
# Profit, 780124.8
# Change from attrition -13
# Profit, 768000.8
# Change from attrition -12
# Profit, 762834.8
# Change from attrition -12
# Profit, 750738.8
# Change from attrition -12
# Profit, 738642.8
# Change from attrition -12
# Profit, 726546.8
# Change from attrition -12
# Profit, 714450.8
# Change from attrition -12
# Profit, 702354.8
# Change from attrition -12
# Profit, 690258.8
# Change from attrition -12
# Profit, 678162.8
# Change from attrition -12
# Profit, 666066.8
# Change from attrition -12
# Profit, 653970.8
# Change from attrition -12
# Profit, 641874.8
# Change from attrition -12
# Profit, 629778.8
# Change from attrition -12
# Profit, 617682.8
# Change from attrition -10
# Profit, 619483.2
# Change from attrition -10
# Profit, 607443.2
# Change from attrition -10
# Profit, 595403.2
# Change from attrition -10
# Profit, 583363.2
# Change from attrition -10
# Profit, 571323.2
# Change from attrition -10
# Profit, 559283.2
# Change from attrition -10
# Profit, 547243.2
# Change from attrition -9
# Profit, 542150.0
# Change from attrition -9
# Profit, 530138.0
# Change from attrition -9
# Profit, 518126.0
# Change from attrition -9
# Profit, 506114.0
# Change from attrition -9
# Profit, 494102.0
# Change from attrition -9
# Profit, 482090.0
# Change from attrition -7
# Profit, 483980.0
# Change from attrition -7
# Profit, 472024.0
# Change from attrition -7
# Profit, 460068.0
# Change from attrition -7
# Profit, 448112.0
# Change from attrition -7
# Profit, 436156.0
# Change from attrition -7
# Profit, 424200.0
# Change from attrition -6
# Profit, 419202.0
# Change from attrition -6
# Profit, 407274.0
# Change from attrition -5
# Profit, 402298.4
# Change from attrition -5
# Profit, 390398.4
# Change from attrition -5
# Profit, 378498.4
# Change from attrition -5
# Profit, 366598.4
# Change from attrition -4
# Profit, 361653.6
# Change from attrition -3
# Profit, 356722.8
# Change from attrition -3
# Profit, 344878.8
# Change from attrition -4
# Profit, 326096.4
# Change from attrition -4
# Profit, 314224.4
# Change from attrition -4
# Profit, 302352.4
# Change from attrition -4
# Profit, 290480.4
# Change from attrition -4
# Profit, 278608.4
# Change from attrition -4
# Profit, 266736.4
# Change from attrition -3
# Profit, 261822.4
# Change from attrition -3
# Profit, 249978.4
# Change from attrition -2
# Profit, 245086.8
# Change from attrition -1
# Profit, 240228.8
# Change from attrition -1
# Profit, 228440.8
# Change from attrition -1
# Profit, 216652.8
# Change from attrition 0
# Profit, 211794.8
# Change from attrition 0
# Profit, 200034.8
# Change from attrition 0
# Profit, 188274.8
# Change from attrition 0
# Profit, 176514.8
# Change from attrition 0
# Profit, 164754.8
# Change from attrition 0
# Profit, 152994.8
# Change from attrition -1
# Profit, 134290.8
# Change from attrition -1
# Profit, 122502.8
# Change from attrition -1
# Profit, 110714.8
# Change from attrition -1
# Profit, 98926.8
# Change from attrition 0
# Profit, 94080.0
# Change from attrition 0
# Profit, 82320.0
# Change from attrition 0
# Profit, 70560.0
# Change from attrition 0
# Profit, 58800.0
# Change from attrition 0
# Profit, 47040.0
# Change from attrition 0
# Profit, 35280.0
# Change from attrition 0
# Profit, 23520.0
# Change from attrition 0
# Profit, 11760.0
# Change from attrition 0
# Profit, 0.0
# Change from attrition 0
# Profit, -11760.0
# Change from attrition 1
# Profit, -16573.2
# Change from attrition 1
# Profit, -28305.2
# Change from attrition 2
# Profit, -33101.600000000006
# Change from attrition 2
# Profit, -44805.600000000006
# Change from attrition 2
# Profit, -56509.600000000006
# Change from attrition 3
# Profit, -61275.2
# Change from attrition 5
# Profit, -59057.600000000006
# Change from attrition 6
# Profit, -63736.40000000001
# Change from attrition 6
# Profit, -75328.40000000001
# Change from attrition 8
# Profit, -73035.20000000001
# Change from attrition 8
# Profit, -84571.20000000001
# Change from attrition 8
# Profit, -96107.20000000001
# Change from attrition 9
# Profit, -100693.6
# Change from attrition 10
# Profit, -105243.6
# Change from attrition 12
# Profit, -102835.6
# Change from attrition 13
# Profit, -107324.00000000001
# Change from attrition 14
# Profit, -111770.40000000001
# Change from attrition 15
# Profit, -116186.00000000001
# Change from attrition 15
# Profit, -127503.60000000002
# Change from attrition 15
# Profit, -138843.60000000003
# Change from attrition 15
# Profit, -150183.60000000003
# Change from attrition 15
# Profit, -161523.60000000003
# Change from attrition 15
# Profit, -172863.60000000003
# Change from attrition 15
# Profit, -184203.6
# Change from attrition 15
# Profit, -195554.8
# Change from attrition 15
# Profit, -206894.8
# Change from attrition 15
# Profit, -218234.8
# Change from attrition 15
# Profit, -229574.8
# Change from attrition 15
# Profit, -240914.8
# Change from attrition 17
# Profit, -238366.80000000002
# Change from attrition 17
# Profit, -249650.80000000002
# Change from attrition 18
# Profit, -253996.40000000002
# Change from attrition 18
# Profit, -265252.4
# Change from attrition 19
# Profit, -269558.80000000005
# Change from attrition 21
# Profit, -266898.80000000005
# Change from attrition 21
# Profit, -278070.80000000005
# Change from attrition 21
# Profit, -289242.80000000005
# Change from attrition 21
# Profit, -300414.80000000005
# Change from attrition 21
# Profit, -311586.80000000005
# Change from attrition 19
# Profit, -336655.2
# Change from attrition 19
# Profit, -347883.2
# Change from attrition 19
# Profit, -359111.2
# Change from attrition 20
# Profit, -363389.60000000003
# Change from attrition 21
# Profit, -367651.20000000007
# Change from attrition 22
# Profit, -371873.60000000003
# Change from attrition 22
# Profit, -383017.60000000003
# Change from attrition 22
# Profit, -394161.6000000001
# Change from attrition 22
# Profit, -405305.6000000001
# Change from attrition 22
# Profit, -416449.6000000001
# Change from attrition 22
# Profit, -427593.6000000001
# Change from attrition 22
# Profit, -438737.6000000001
# Change from attrition 22
# Profit, -449881.6000000001
# Change from attrition 22
# Profit, -461025.6000000001
# Change from attrition 22
# Profit, -472169.6000000001
# Change from attrition 22
# Profit, -483313.6000000001
# Change from attrition 22
# Profit, -494457.6000000001
# Change from attrition 22
# Profit, -505601.6000000001
# Change from attrition 22
# Profit, -516745.6000000001
# Change from attrition 22
# Profit, -527889.6000000001
# Change from attrition 22
# Profit, -539033.6000000001
# Change from attrition 22
# Profit, -550177.6000000001
# Change from attrition 22
# Profit, -561321.6000000001
# Change from attrition 22
# Profit, -572465.6000000001
# Change from attrition 22
# Profit, -583609.6000000001
# Change from attrition 22
# Profit, -594753.6000000001
# Change from attrition 22
# Profit, -605897.6000000001
# Change from attrition 22
# Profit, -617041.6000000001
# Change from attrition 22
# Profit, -628185.6000000001
# Change from attrition 22
# Profit, -639329.6000000001
# Change from attrition 22
# Profit, -650473.6000000001
# Change from attrition 22
# Profit, -661617.6000000001
# Change from attrition 22
# Profit, -672761.6000000001
# Change from attrition 22
# Profit, -683905.6000000001
# Change from attrition 22
# Profit, -695049.6000000001
# Change from attrition 22
# Profit, -706193.6000000001
# Change from attrition 22
# Profit, -717337.6000000001
# Change from attrition 22
# Profit, -728481.6000000001
# Change from attrition 22
# Profit, -739625.6000000001
# Change from attrition 22
# Profit, -750769.6000000001
# Change from attrition 23
# Profit, -754955.6000000001
# Change from attrition 23
# Profit, -766071.6000000001
# Change from attrition 23
# Profit, -777187.6000000001
# Change from attrition 23
# Profit, -788303.6000000001
# Change from attrition 23
# Profit, -799419.6000000001
# Change from attrition 23
# Profit, -810535.6000000001
# Change from attrition 23
# Profit, -821651.6000000001
# Change from attrition 23
# Profit, -832767.6000000001
# Change from attrition 23
# Profit, -843883.6000000001
# Change from attrition 23
# Profit, -854999.6000000001
# Change from attrition 23
# Profit, -866115.6000000001
# Change from attrition 23
# Profit, -877231.6000000001
# Change from attrition 23
# Profit, -888347.6000000001
# Change from attrition 23
# Profit, -899463.6000000001
# Change from attrition 23
# Profit, -910579.6000000001
# Change from attrition 23
# Profit, -921695.6000000001
# Change from attrition 23
# Profit, -932811.6000000001
# Change from attrition 23
# Profit, -943927.6000000001
# Change from attrition 23
# Profit, -955043.6000000001

# %%
plt.plot(range(-1000, 1000, 10), profit)
plt.xlabel('Rasied amount')
plt.ylabel('profit level')
plt.show()

# %% [markdown]
# ## ANSWER :
#
# The plot shows, the more money you raise for employee, the less profit you make for the company. Thus, you need to keep employee busy while reducing their payment.
